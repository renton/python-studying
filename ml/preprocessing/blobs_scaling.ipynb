# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler

# %%
# what will happen if we use the minimum and range on the test set (instead of the scaling from the training set)
X, _ = make_blobs(n_samples=500, centers=5, random_state=4, cluster_std=2)

X_train, X_test = train_test_split(X, random_state=5, test_size=.1)

[
    X_train.shape,
    X_test.shape,
]
# Out:
# [(450, 2), (50, 2)]

# %%
fig, axes= plt.subplots(1, 3, figsize=(13, 4))

axes[0].scatter(X_train[:, 0], X_train[:, 1], c=mglearn.cm2(0), label="training set", s=60, marker="^")
axes[0].scatter(X_test[:, 0], X_test[:, 1], c=mglearn.cm2(0), label="test set", s=60)

axes[0].legend(loc='upper left')
axes[0].set_title("Original Data")

# scale data using MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

axes[1].scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=mglearn.cm2(0), label="training set", s=60, marker="^")
axes[1].scatter(X_test_scaled[:, 0], X_test_scaled[:, 1], c=mglearn.cm2(0), label="test set", s=60)
axes[1].set_title("scaled data")

# scale the test set separately for demonstration purposes. DO NOT DO THIS!
test_scaler = MinMaxScaler()
test_scaler.fit(X_test)

X_test_scaled_badly = test_scaler.transform(X_test)

axes[2].scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=mglearn.cm2(0), label="training set", s=60, marker="^")
axes[2].scatter(X_test_scaled_badly[:, 0], X_test_scaled_badly[:, 1], c=mglearn.cm2(0), label="test set", s=60)
axes[2].set_title("improperly scaled data")

for ax in axes:
    ax.set_xlabel("feature0")
    ax.set_ylabel("feature1")
fig.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_480488/3834070694.py:3: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[0].scatter(X_train[:, 0], X_train[:, 1], c=mglearn.cm2(0), label="training set", s=60, marker="^")
# /tmp/ipykernel_480488/3834070694.py:4: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[0].scatter(X_test[:, 0], X_test[:, 1], c=mglearn.cm2(0), label="test set", s=60)
# ...
